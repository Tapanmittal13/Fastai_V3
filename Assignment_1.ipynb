# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button. Then continue scrolling until you cannot scroll anymore. The maximum number of images Google Images shows is 700.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
from fastai import *
from fastai.vision import *

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
folder = 'Airbus_320'
file = 'A320'

# %%
folder = 'Boeing_A737'
file = '737'

# %%
folder = 'Bombardier_CS300'
file = 'CS300'

# %% [markdown]
# You will need to run this line once per each category.

# %%
# path = Path('data/sweets_india')
# dest = path/folder
# dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images than can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
path = Path('data/Aircarft')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:18<00:00]
#     </div>
# Error https://imgproc.airliners.net/photos/airliners/7/7/9/2598977.jpg?v=v40 'content-length'
# Error https://imgproc.airliners.net/photos/airliners/3/6/3/4601363.jpg?v=v488b25b8d5d 'content-length'
# Error https://www.bombardier.com/content/dam/Websites/bombardiercom/News/BA/20161202%20BCACS300-Q400-air-tanzania-sky_HR.jpg/_jcr_content/renditions/cq5dam.web.750.750.jpeg 'content-length'
# Error https://imgproc.airliners.net/photos/airliners/1/3/1/4617131.jpg?v=v4468a32fe9b 'content-length'
# Error https://www.flightglobal.com/assets/getasset.aspx?itemid=73242 'content-length'
# Error https://cdn.planespotters.net/photo/798000/original/yl-csc-air-baltic-bombardier-cseries-cs300-bd-500-1a11_PlanespottersNet_798364_f2d21a8039.jpg 'content-length'
# Error http://infoaeroquebec.net/wp-content/uploads/2016/12/Tanzania-Q400-CS300.jpeg 'content-length'
# Error https://cdn.planespotters.net/photo/845000/original/hb-jcm-swiss-bombardier-cseries-cs300-bd-500-1a11_PlanespottersNet_845973_ca808d6db6.jpg 'content-length'
# Error https://c8.alamy.com/comp/P73ECT/mirabel-canada-july-4-2018-a-bombardier-cs-300-passenger-jet-sitting-outside-bombardiers-assembly-plantcreditmario-beauregardalamy-live-news-P73ECT.jpg 'content-length'
# Error https://images4.sw-cdn.net/product/picture/710x528_19327085_10293437_1498583307.jpg 'content-length'
# Error https://cdn.planespotters.net/photo/729000/original/c-ffdo-bombardier-bombardier-cseries-cs300-bd-500-1a11_PlanespottersNet_729601_c7c4a74987.jpg 'content-length'

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
classes = ['Airbus_320','Boeing_A737','Bombardier_CS300']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# Airbus_320
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='193' class='' max='193', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [193/193 00:04<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Airbus_320/00000022.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Airbus_320/00000154.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Airbus_320/00000142.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Airbus_320/00000198.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Airbus_320/00000119.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Airbus_320/00000024.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Airbus_320/00000112.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Airbus_320/00000067.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Airbus_320/00000152.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Airbus_320/00000134.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Airbus_320/00000162.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Airbus_320/00000140.jpg'
# Boeing_A737
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='193' class='' max='193', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [193/193 00:04<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000021.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000115.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000193.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000181.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000146.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000023.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000176.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000083.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000136.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000197.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000017.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000104.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000158.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000134.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000071.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000060.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000014.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000057.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000156.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000155.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000187.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Boeing_A737/00000044.jpg'
# Bombardier_CS300
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='189' class='' max='189', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [189/189 00:05<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Bombardier_CS300/00000086.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Bombardier_CS300/00000179.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Bombardier_CS300/00000104.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Bombardier_CS300/00000171.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Bombardier_CS300/00000009.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Bombardier_CS300/00000072.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Bombardier_CS300/00000071.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Aircarft/Bombardier_CS300/00000057.jpg'

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['Airbus_320', 'Boeing_A737', 'Bombardier_CS300']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Airbus_320', 'Boeing_A737', 'Bombardier_CS300'], 3, 414, 119)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.410064    0.952945    0.487395    (00:15)
# 2      1.170848    0.817845    0.386555    (00:13)
# 3      1.043966    0.794934    0.327731    (00:14)
# 4      0.942247    0.807987    0.344538    (00:13)

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-4,1e-3))
# Out:
# Total time: 00:28
# epoch  train_loss  valid_loss  error_rate
# 1      0.763993    1.115983    0.453781    (00:13)
# 2      0.631882    1.530777    0.487395    (00:14)

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9)
